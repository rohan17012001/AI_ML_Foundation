# %% [markdown]
# # Conditional Probability
#
# Let's say A and B are two events. Let $P(A)$ and $P(B)$ be the individual probabilities of these events. Let $P(A, B)$ be the probability of both the events occuring together.
# The probability $P(B|A)$, which means the probability of event B occuring if the event A has occured is given by:
#
# $ P(B|A) = \frac{P(A,B)}{P(A)} $
#
#
# For our experiment, we are measuring the probability of people from a certain age group buying a product.
#
# We have the following age groups: 20s, 30s, 40s, 50s, 60s, 70s
#
# We have 2 dictionaries:
# - totals, which stores the count of total people from each age group, and
# - purchases, which stores the count of people who bought the product from each age group.

# %%
from numpy import random
random.seed(0)

totals = {20:0, 30:0, 40:0, 50:0, 60:0, 70:0}
purchases = {20:0, 30:0, 40:0, 50:0, 60:0, 70:0}
totalPurchases = 0
for _ in range(100000):
    ageDecade = random.choice([20, 30, 40, 50, 60, 70])
    
    # We are calculating the probability of each age group buying our stuff.
    # So, a 20 year old will have a probability of 20%, 30 year will have 30%, and so on

    purchaseProbability = float(ageDecade)/100
    totals[ageDecade]+=1

    # random.random() gives a number between 0 and 1
    # If its value is less than purchaseProbability, it means that the person bought the product.
    # eg: if random.random()=0.11 and purchaseProbability = 0.20, it means that the person bought the product
    # and vice versa.

    if(random.random()<purchaseProbability):
        totalPurchases+=1
        purchases[ageDecade]+=1

# %%
totals
# Out:
# {20: 16576, 30: 16619, 40: 16632, 50: 16805, 60: 16664, 70: 16704}

# %%
purchases
# Out:
# {20: 3392, 30: 4974, 40: 6670, 50: 8319, 60: 9944, 70: 11713}

# %%
totalPurchases
# Out:
# 45012

# %% [markdown]
# Let E be the event of purchase, and F be the even of being in your 30s.
#
# $P(E|F)$, i.e., the probability of purchasing if you are in your 30s:

# %%
PEF = purchases[30]/totals[30]
print(f'P(purchase | 30s): {PEF}')
# Out:
# P(purchase | 30s): 0.29929598652145134

# %% [markdown]
# $P(F)$ is the probability of being in your 30s

# %%
PF=totals[30]/100000
print(f'P(30s) = {PF}')
# Out:
# P(30s) = 0.16619

# %% [markdown]
# $P(E)$ is the probability of purchasing, regardless

# %%
PE = totalPurchases/100000
print(f'P(purchase) = {PE}')
# Out:
# P(purchase) = 0.45012

# %% [markdown]
# If E and F were independent, then $P(E|F)$ should have been the same as $P(E)$. But they are not. It clearly means that there is a relationship between the values. We have explicitly established a relationship between them.

# %% [markdown]
# $P(E,F)$ is the probability of both being in your 30s and buying something, out of the total population, and not just from the population of the 30s

# %%
PEnF = float(purchases[30]/100000)
print(f'P(E,F) = {PEnF}')
# Out:
# P(E,F) = 0.04974

# %% [markdown]
# Lets compute $P(E)*P(F)$

# %%
PEPF = PE * PF
print(f'P(E)*P(F) = {PEPF}')
# Out:
# P(E)*P(F) = 0.07480544280000001

# %% [markdown]
# If $P(E)$ and $P(F)$ were truly independent, then $P(E,F)$ would have been equal to $P(E)*P(F)$, but they are not. It also shows that there is dependency between the two.
#
# We can independently calculate $P(E|F)$, which is given by:

# %%
PCond = PEnF/PF
print(f'Conditional probability P(E|F) = {PCond}')
# Out:
# Conditional probability P(E|F) = 0.29929598652145134

# %% [markdown]
# , which is the same as the value calculated above

# %%
PCond == PEF
# Out:
# True
